# %%
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale 
from sklearn import model_selection
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')


df = pd.read_csv("StudentPerformanceFactors.csv")
df = df.select_dtypes(include = ['float64', 'int64']) 
df.dropna()
df.copy()
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  \
# 0             23          84            7               73                  0
# 1             19          64            8               59                  2
# 2             24          98            7               91                  2
# 3             29          89            8               98                  1
# 4             19          92            6               65                  3
#
#    Physical_Activity  Exam_Score
# 0                  3          67
# 1                  4          61
# 2                  4          74
# 3                  4          71
# 4                  4          70

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.corr()  #ı looked at the correlation of the data
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.009908     0.010977         0.024846
# Attendance             -0.009908    1.000000    -0.015918        -0.020186
# Sleep_Hours             0.010977   -0.015918     1.000000        -0.021750
# Previous_Scores         0.024846   -0.020186    -0.021750         1.000000
# Tutoring_Sessions      -0.014282    0.014324    -0.012216        -0.013122
# Physical_Activity       0.004624   -0.022435    -0.000378        -0.011274
# Exam_Score              0.445455    0.581072    -0.017022         0.175079
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.014282           0.004624    0.445455
# Attendance                  0.014324          -0.022435    0.581072
# Sleep_Hours                -0.012216          -0.000378   -0.017022
# Previous_Scores            -0.013122          -0.011274    0.175079
# ...

# %%
sns.pairplot(df, kind  ="reg");   #I visualized the correlation of the data

# %%
df.apply(lambda x: x.fillna(x.mean()), axis = 0)
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6602             25          69            7               76
# 6603             23          76            8               81
# 6604             20          90            6               65
# 6605             10          86            6               91
# 6606             15          67            9               94
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score
# 0                     0                  3          67
# 1                     2                  4          61
# ...

# %%
df.corr()
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.009908     0.010977         0.024846
# Attendance             -0.009908    1.000000    -0.015918        -0.020186
# Sleep_Hours             0.010977   -0.015918     1.000000        -0.021750
# Previous_Scores         0.024846   -0.020186    -0.021750         1.000000
# Tutoring_Sessions      -0.014282    0.014324    -0.012216        -0.013122
# Physical_Activity       0.004624   -0.022435    -0.000378        -0.011274
# Exam_Score              0.445455    0.581072    -0.017022         0.175079
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.014282           0.004624    0.445455
# Attendance                  0.014324          -0.022435    0.581072
# Sleep_Hours                -0.012216          -0.000378   -0.017022
# Previous_Scores            -0.013122          -0.011274    0.175079
# ...

# %%
df.isnull().sum().sum()  #doesn't have null data.
# Out:
# 0

# %%
df.Exam_Score.mean()
# Out:
# 67.23565914938702

# %%
import statsmodels.api as sm

# %%
X = df[["Attendance"]]
X[0:5]
# Out:
#    Attendance
# 0          84
# 1          64
# 2          98
# 3          89
# 4          92

# %%
X = sm.add_constant(X)
X[0:5]
# Out:
#    const  Attendance
# 0    1.0          84
# 1    1.0          64
# 2    1.0          98
# 3    1.0          89
# 4    1.0          92

# %%
y = df["Exam_Score"]
y[0:5]
# Out:
# 0    67
# 1    61
# 2    74
# 3    71
# 4    70
# Name: Exam_Score, dtype: int64

# %%
lm = sm.OLS(y,X)

# %%
model = lm.fit()

# %%
model.summary()  #ı looked at the statistical values.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Exam_Score   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     3367.
# Date:                Sun, 22 Sep 2024   Prob (F-statistic):               0.00
# Time:                        13:44:52   Log-Likelihood:                -16989.
# No. Observations:                6607   AIC:                         3.398e+04
# Df Residuals:                    6605   BIC:                         3.400e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         51.5786      0.273    189.191      0.000      51.044      52.113
# ...

# %%
X = df["Hours_Studied" ,"Attendance"]

# %%
hit = pd.read_csv("StudentPerformanceFactors.csv")

df = hit.copy()
df = df.dropna()

# %%
Parental_Involvement', 'School_Type', 'Access_to_Resources', 'Peer_Influence',"Parental_Education_Level"
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
dms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
y = df["Salary"]
 #I looked at the nonlinear values with xgboost
X = pd.df["Hours_Studied" ,"Attendance"]
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 dms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
#       2 y = df["Salary"]
#       3  #I looked at the nonlinear values with xgboost
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
# ...
